# %%
import numpy as np
import matplotlib.pyplot as pl
import pandas as pd

# %%
data = pd.read_csv('data.csv', skipinitialspace=True, header=0)
data= pd.DataFrame(data)
my_data = data.iloc[:, 9: 18]
my_data
# Out:
#                 fuel_type             power                        seller  \
# 0      \r\n,Gasoline,\r\n  110 kW (150 hp),          ['\n', ['Dealer\n']]
# 1      \r\n,Gasoline,\r\n   92 kW (125 hp),          ['\n', ['Dealer\n']]
# 2      \r\n,Gasoline,\r\n   92 kW (125 hp),          ['\n', ['Dealer\n']]
# 3      \r\n,Gasoline,\r\n   92 kW (125 hp),          ['\n', ['Dealer\n']]
# 4      \r\n,Gasoline,\r\n  110 kW (150 hp),          ['\n', ['Dealer\n']]
# ...                   ...               ...                           ...
# 62761       \r\n,LPG,\r\n  125 kW (170 hp),          ['\n', ['Dealer\n']]
# 62762       \r\n,LPG,\r\n  103 kW (140 hp),          ['\n', ['Dealer\n']]
# 62763       \r\n,LPG,\r\n  132 kW (179 hp),          ['\n', ['Dealer\n']]
# 62764       \r\n,LPG,\r\n  103 kW (140 hp),  ['\n', ['Private seller\n']]
# 62765       \r\n,LPG,\r\n  104 kW (141 hp),          ['\n', ['Dealer\n']]
#
#                body_type            type       drivetrain  seats  doors  \
# ...

# %%
my_data = my_data.applymap(lambda x: x.strip('\r\n'))
my_data = my_data.applymap(lambda x: x.strip(','))
my_data['seller'] = my_data['seller'].apply(lambda x: x.strip('["\n\']').strip('\\').strip('n').split(',')[0].strip("['").replace("['", '') if isinstance(x, str) else x)
my_data['country_version'] = my_data['country_version'].str.split(',').str[1]


my_data.tail(20)
# Out:
# C:\Users\jos_m\AppData\Local\Temp\ipykernel_16548\4161656520.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   my_data = my_data.applymap(lambda x: x.strip('\r\n'))
# C:\Users\jos_m\AppData\Local\Temp\ipykernel_16548\4161656520.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   my_data = my_data.applymap(lambda x: x.strip(','))
#       fuel_type            power           seller      body_type  type  \
# 62746       LPG   90 kW (122 hp)           Dealer  Station wagon  Used
# 62747       LPG  147 kW (200 hp)           Dealer  Station wagon  Used
# 62748       LPG  103 kW (140 hp)           Dealer  Station wagon  Used
# 62749       LPG  103 kW (140 hp)           Dealer  Station wagon  Used
# 62750       LPG  147 kW (200 hp)           Dealer  Station wagon  Used
# 62751       LPG  104 kW (141 hp)           Dealer  Station wagon  Used
# ...
